# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv(r"C:\Users\Lenovo\Veri Analizi Projelerim\verisetleri\lol.csv")

# %%
df.head(3)
# Out:
#      Name           Tags        Role Range type Resourse type  Base HP  \
# 0  Aatrox        Fighter         Top      Melee    Blood Well      650
# 1    Ahri  Mage,Assassin      Middle     Ranged          Mana      590
# 2   Akali       Assassin  Top,Middle      Melee        Energy      600
#
#    HP per lvl  Base mana  Mana per lvl  Movement speed  ...  Attack range  \
# 0         114          0           0.0             345  ...           175
# 1         104        418          25.0             330  ...           550
# 2         119        200           0.0             345  ...           125
#
#    HP regeneration  HP regeneration per lvl  Mana regeneration  \
# 0              3.0                      0.5                0.0
# 1              2.5                      0.6                8.0
# 2              9.0                      0.9               50.0
#
#    Mana regeneration per lvl  Attack damage  Attack damage per lvl  \
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Tags', 'Role', 'Range type', 'Resourse type', 'Base HP',
#        'HP per lvl', 'Base mana', 'Mana per lvl', 'Movement speed',
#        'Base armor', 'Armor per lvl', 'Base magic resistance',
#        'Magic resistance per lvl', 'Attack range', 'HP regeneration',
#        'HP regeneration per lvl', 'Mana regeneration',
#        'Mana regeneration per lvl', 'Attack damage', 'Attack damage per lvl',
#        'Attack speed per lvl', 'Attack speed', 'AS ratio'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Name                         0
# Tags                         0
# Role                         0
# Range type                   0
# Resourse type                7
# Base HP                      0
# HP per lvl                   0
# Base mana                    0
# Mana per lvl                 0
# Movement speed               0
# Base armor                   0
# Armor per lvl                0
# Base magic resistance        0
# Magic resistance per lvl     0
# Attack range                 0
# HP regeneration              0
# HP regeneration per lvl      0
# Mana regeneration            0
# Mana regeneration per lvl    0
# Attack damage                0
# Attack damage per lvl        0
# Attack speed per lvl         0
# Attack speed                 0
# AS ratio                     0
# dtype: int64

# %%
df.head(10)
# Out:
#        Name               Tags            Role Range type Resourse type  \
# 0    Aatrox            Fighter             Top      Melee    Blood Well
# 1      Ahri      Mage,Assassin          Middle     Ranged          Mana
# 2     Akali           Assassin      Top,Middle      Melee        Energy
# 3    Akshan  Marksman,Assassin          Middle     Ranged          Mana
# 4   Alistar       Tank,Support         Support      Melee          Mana
# 5     Amumu       Tank,Support  Jungle,Support      Melee          Mana
# 6    Anivia               Mage          Middle     Ranged          Mana
# 7     Annie       Mage,Support          Middle     Ranged          Mana
# 8  Aphelios           Marksman          Bottom     Ranged          Mana
# 9      Ashe   Marksman,Support  Bottom,Support     Ranged          Mana
#
#    Base HP  HP per lvl  Base mana  Mana per lvl  Movement speed  ...  \
# 0      650         114          0           0.0             345  ...
# ...

# %%
df['Resourse type'].fillna('Mana', inplace=True)

# %%
df.isnull().sum()
# Out:
# Name                         0
# Tags                         0
# Role                         0
# Range type                   0
# Resourse type                0
# Base HP                      0
# HP per lvl                   0
# Base mana                    0
# Mana per lvl                 0
# Movement speed               0
# Base armor                   0
# Armor per lvl                0
# Base magic resistance        0
# Magic resistance per lvl     0
# Attack range                 0
# HP regeneration              0
# HP regeneration per lvl      0
# Mana regeneration            0
# Mana regeneration per lvl    0
# Attack damage                0
# Attack damage per lvl        0
# Attack speed per lvl         0
# Attack speed                 0
# AS ratio                     0
# dtype: int64

# %%
df.dtypes
# Out:
# Name                          object
# Tags                          object
# Role                          object
# Range type                    object
# Resourse type                 object
# Base HP                        int64
# HP per lvl                     int64
# Base mana                      int64
# Mana per lvl                 float64
# Movement speed                 int64
# Base armor                     int64
# Armor per lvl                float64
# Base magic resistance          int64
# Magic resistance per lvl     float64
# Attack range                   int64
# HP regeneration              float64
# HP regeneration per lvl      float64
# Mana regeneration            float64
# Mana regeneration per lvl    float64
# Attack damage                  int64
# Attack damage per lvl        float64
# Attack speed per lvl         float64
# Attack speed                 float64
# AS ratio                     float64
# dtype: object

# %%
sorted_by_mana= df.sort_values(by="Base mana",ascending=False)

# %%
sorted_by_mana
# Out:
#              Name              Tags            Role Range type Resourse type  \
# 10   Aurelion Sol              Mage          Middle     Ranged          Mana
# 31   Fiddlesticks      Mage,Support          Jungle     Ranged          Mana
# 34          Galio         Tank,Mage  Middle,Support      Melee          Mana
# 157          Yone  Fighter,Assassin      Top,Middle      Melee          Flow
# 6          Anivia              Mage          Middle     Ranged          Mana
# ..            ...               ...             ...        ...           ...
# 114          Sett      Fighter,Tank             Top      Melee          Grit
# 147         Viego  Fighter,Assassin          Jungle      Melee          Mana
# 17          Briar  Fighter,Assassin          Jungle      Melee          Fury
# 26      Dr. Mundo      Tank,Fighter             Top      Melee          Mana
# 0          Aatrox           Fighter             Top      Melee    Blood Well
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(x=sorted_by_mana["Base mana"][:10], y=sorted_by_mana["Name"][:10])
plt.xlabel("Base Mana")
plt.ylabel("Name")
# Out:
# Text(0, 0.5, 'Name')

# %%
# grafik boyutunu ayarlama
plt.figure(figsize=(12, 6))  # genişlik=12, yükseklik=6 olarak ayarlanıyor

# bar grafiğini oluşturma
sns.barplot(x=sorted_by_attack_damage["Name"][:10], y=sorted_by_attack_damage["Attack damage"][:10])

plt.title("Top 10 Characters by Attack Damage")
plt.xlabel("Name")
plt.ylabel("Attack Damage")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 5
#       2 plt.figure(figsize=(12, 6))  # genişlik=12, yükseklik=6 olarak ayarlanıyor
#       4 # bar grafiğini oluşturma
# ----> 5 sns.barplot(x=sorted_by_attack_damage["Name"][:10], y=sorted_by_attack_damage["Attack damage"][:10])
#       7 plt.title("Top 10 Characters by Attack Damage")
#       8 plt.xlabel("Name")
#
# NameError: name 'sorted_by_attack_damage' is not defined

# %%
df.describe()
# Out:
#           Base HP  HP per lvl   Base mana  Mana per lvl  Movement speed  \
# count  167.000000  167.000000  167.000000    167.000000      167.000000
# mean   617.856287  104.059880  313.586826     36.712575      336.155689
# std     39.468040    8.687133  122.071293     19.780376        7.060817
# min    410.000000   69.000000    0.000000      0.000000      325.000000
# 25%    595.500000   99.000000  280.000000     25.500000      330.000000
# 50%    625.000000  104.000000  330.000000     40.000000      335.000000
# 75%    645.000000  109.000000  392.500000     50.000000      340.000000
# max    696.000000  129.000000  530.000000     87.000000      355.000000
#
#        Base armor  Armor per lvl  Base magic resistance  \
# count  167.000000      167.00000             167.000000
# mean    29.886228        4.64521              30.760479
# std      6.400696        0.51391               1.701203
# min     18.000000        0.00000              22.000000
# ...

# %%
mana_items= df[df["Resourse type"]=="Mana"]
mana_counts = mana_items['Name'].value_counts()
mana_counts
# Out:
# Ahri            1
# Swain           1
# Rell            1
# Renata Glasc    1
# Riven           1
#                ..
# Kai'Sa          1
# Kalista         1
# Karma           1
# Karthus         1
# Zyra            1
# Name: Name, Length: 147, dtype: int64

# %%
# hangi karakter ne kullanıyor

plt.figure(figsize=(12, 6)) 

sns.swarmplot(x=df["Name"][:20], 
              y=df["Resourse type"][:20], 
              size=10, palette="Set2", hue=df["Resourse type"][:20])

plt.title("Characters by Resourse type")
plt.xlabel("Name")
plt.ylabel("Resourse type")
plt.xticks(rotation=45)  # isimleri daha net görmek için döndürme

plt.legend(title="Resourse type", bbox_to_anchor=(1.05, 1), loc='upper left', frameon=True)

plt.show()

# %%
# hangi karakter nerelerde oynuyor
plt.figure(figsize=(12, 6)) 

sns.swarmplot(x=df["Name"][:15], 
              y=df["Role"][:15], 
              size=10, palette="Set2", hue=df["Role"][:15])

plt.title("Characters by Resourse type")
plt.xlabel("Name")
plt.ylabel("Resourse type")
plt.xticks(rotation=45) 

plt.legend(title="Resourse type", bbox_to_anchor=(1.05, 1), loc='upper left', frameon=True)

plt.show()

# %%
df.hist(bins=30, figsize=(20, 20), grid=False)
plt.suptitle('Feature Distributions')
plt.show()
